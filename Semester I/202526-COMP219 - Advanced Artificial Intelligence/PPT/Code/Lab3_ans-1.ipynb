# %% [markdown]
# # COMP219
# ## Lab 3
# In the first two weeks of labs, we introduced notebooks and performed some basic visualisation. This week, we will look at implementing ID3 (iterative dichotomiser 3), a variant of the decision tree algorithm.
#
#
# ### Getting Set Up
# We will need various libraries for today's lab, let's import them. We will also import the diabetes dataset, found [here](https://github.com/plotly/datasets/blob/master/diabetes.csv). You do not need to have any medical (or similar) background. However, for context, we are looking to predict diabetes in individuals based on a score called the diabetes pedigree. There are many factors, such as glucose, age, and so on (see the column names in the dataset) that can help us predict the individual's diabetes status.

# %%
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree 
import matplotlib.pyplot as plt 
import math

dataset = pd.read_csv('diabetes.csv') 
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Implementing ID3
# In the lectures, we covered how ID3 works. Recall that:
# - ID3's splitting criterion is based on information gain
# - It can only handle categorical (discrete) values
# - It cannot handle missing values
# - It performs no pruning
# - It is susceptible to outliers.
#
# #### Entropy and Information Gain
#
# We need to calculate entropy, which will help us measure the amount of uncertainty (impurity) in the data. This will guide us during the construction of the tree by determining the best attribute for splitting at each step.
#
# The process of splitting is done by calculating information gain. We are looking to maximise information gain at each split to minimise uncertainty and maximise homogeneity in the resulting subsets of data.

# %%
# --- Entropy calculation ---
def calculate_entropy(data, target_column): 
    total_rows = len(data) 
    target_values = data[target_column].unique()
    entropy = 0
    for value in target_values: 
        value_count = len(data[data[target_column] == value]) 
        proportion = value_count / total_rows 
        if proportion != 0:
            entropy -= proportion * math.log2(proportion)
    return entropy 

# --- Information Gain calculation ---
def calculate_information_gain(data, feature, target_column): 
    total_entropy = calculate_entropy(data, target_column)
    weighted_entropy = 0
    for value in data[feature].unique(): 
        subset = data[data[feature] == value]
        proportion = len(subset) / len(data)
        weighted_entropy += proportion * calculate_entropy(subset, target_column)
    return total_entropy - weighted_entropy

# %% [markdown]
# #### ID3 In Detail
#
# The third function we need to define is one that builds the ID3. First, we check if the target feature has a single unique value (it should not). We then check if all features have been used or if the remaining features provide no more information gain. Feature selection is done based on information gain - we choose the feature with the highest information gain. We then proceed to create a subtree for that feature. We then split the best feature to build further subtrees for each of its unique values.

# %%
def id3(data, target_column, features): 
    # If all examples have the same label, return it
    if len(data[target_column].unique()) == 1: 
        return data[target_column].iloc[0]
    
    # If no features left, return majority class
    if len(features) == 0: 
        return data[target_column].mode().iloc[0]
    
    # Choose the feature with the highest information gain
    best_feature = max(features, key=lambda x: calculate_information_gain(data, x, target_column))
    
    tree = {best_feature: {}}
    
    remaining_features = [f for f in features if f != best_feature]
    
    for value in data[best_feature].unique(): 
        subset = data[data[best_feature] == value]
        subtree = id3(subset, target_column, remaining_features)
        tree[best_feature][value] = subtree
    
    return tree

# %%
outcome_entr = calculate_entropy(dataset, 'Outcome') 
print(f"Entropy of the dataset: {outcome_entr}")
# Out:
# Entropy of the dataset: 0.9331343166407831

# %%
from sklearn.tree import export_text

for column in dataset.columns[:-1]: 
	entropy = calculate_entropy(dataset, column) 
	information_gain = calculate_information_gain(dataset, column, 'Outcome') 
	print(f"{column} - Entropy: {entropy:.3f}, Information Gain: {information_gain:.3f}")

# Feature selection for the first step in making decision tree 
#selected_feature = 'DiabetesPedigreeFunction'

X = dataset.drop(columns=['Outcome'])
y = dataset['Outcome']

clf = DecisionTreeClassifier(criterion='entropy', max_depth=50, random_state=42)
clf.fit(X, y)

r = export_text(clf, feature_names=list(X.columns))
print(r)

plt.figure(figsize=(20, 10))
plot_tree(
    clf,
    feature_names=X.columns,
    class_names=['No Diabetes', 'Diabetes'],
    filled=True,
    rounded=True
)
plt.title("Decision Tree Trained on Clean Dataset")
plt.show()

plt.savefig("decision_tree_full.svg", format='svg', dpi=300)
# Out:
# Pregnancies - Entropy: 3.482, Information Gain: 0.062
# Glucose - Entropy: 6.751, Information Gain: 0.304
# BloodPressure - Entropy: 4.792, Information Gain: 0.059
# SkinThickness - Entropy: 4.586, Information Gain: 0.082
# Insulin - Entropy: 4.682, Information Gain: 0.277
# BMI - Entropy: 7.594, Information Gain: 0.344
# DiabetesPedigreeFunction - Entropy: 8.829, Information Gain: 0.651
# Age - Entropy: 5.029, Information Gain: 0.141
# |--- Glucose <= 127.50
# |   |--- Age <= 28.50
# |   |   |--- BMI <= 30.95
# |   |   |   |--- Pregnancies <= 7.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.67
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.67
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.69
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.69
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Pregnancies >  7.50
# |   |   |   |   |--- class: 1
# |   |   |--- BMI >  30.95
# |   |   |   |--- BloodPressure <= 37.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- BloodPressure >  37.00
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.50
# |   |   |   |   |   |--- BMI <= 45.35
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.28
# |   |   |   |   |   |   |   |--- Insulin <= 89.00
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 55.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- BloodPressure >  55.00
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.27
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 94.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  94.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Insulin >  89.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.28
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BMI >  45.35
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.50
# |   |   |   |   |   |--- BMI <= 38.65
# |   |   |   |   |   |   |--- SkinThickness <= 39.50
# |   |   |   |   |   |   |   |--- BMI <= 32.20
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BMI >  32.20
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 61.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BloodPressure >  61.00
# |   |   |   |   |   |   |   |   |   |--- BMI <= 34.30
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 32.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  32.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BMI >  34.30
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 36.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  36.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- SkinThickness >  39.50
# |   |   |   |   |   |   |   |--- SkinThickness <= 42.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- SkinThickness >  42.50
# |   |   |   |   |   |   |   |   |--- Insulin <= 128.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Insulin >  128.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BMI >  38.65
# |   |   |   |   |   |   |--- Age <= 21.50
# |   |   |   |   |   |   |   |--- Pregnancies <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pregnancies >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Age >  21.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- Age >  28.50
# |   |   |--- BMI <= 26.35
# |   |   |   |--- BMI <= 9.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- BMI >  9.65
# |   |   |   |   |--- class: 0
# |   |   |--- BMI >  26.35
# |   |   |   |--- Glucose <= 99.50
# |   |   |   |   |--- Glucose <= 28.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Glucose >  28.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.80
# |   |   |   |   |   |   |--- Age <= 42.50
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.17
# |   |   |   |   |   |   |   |   |--- SkinThickness <= 18.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SkinThickness >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.17
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Age >  42.50
# |   |   |   |   |   |   |   |--- SkinThickness <= 24.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- SkinThickness >  24.00
# |   |   |   |   |   |   |   |   |--- SkinThickness <= 31.50
# |   |   |   |   |   |   |   |   |   |--- Glucose <= 72.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Glucose >  72.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SkinThickness >  31.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.80
# |   |   |   |   |   |   |--- SkinThickness <= 35.50
# |   |   |   |   |   |   |   |--- Pregnancies <= 6.00
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.11
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.11
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pregnancies >  6.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SkinThickness >  35.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Glucose >  99.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.56
# |   |   |   |   |   |--- Age <= 54.50
# |   |   |   |   |   |   |--- BMI <= 27.55
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  27.55
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.20
# |   |   |   |   |   |   |   |   |--- Pregnancies <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Pregnancies >  5.50
# |   |   |   |   |   |   |   |   |   |--- BMI <= 34.55
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 118.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  118.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BMI >  34.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.20
# |   |   |   |   |   |   |   |   |--- Pregnancies <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Glucose <= 113.00
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 36.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  36.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Glucose >  113.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Pregnancies >  1.50
# |   |   |   |   |   |   |   |   |   |--- Insulin <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 105.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  105.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Insulin >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- Age >  54.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.56
# |   |   |   |   |   |--- Pregnancies <= 6.50
# |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |--- Age <= 34.50
# |   |   |   |   |   |   |   |   |--- BMI <= 27.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- BMI >  27.20
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Age >  34.50
# |   |   |   |   |   |   |   |   |--- BMI <= 33.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- BMI >  33.15
# |   |   |   |   |   |   |   |   |   |--- Age <= 55.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Age >  55.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Pregnancies >  6.50
# |   |   |   |   |   |   |--- class: 1
# |--- Glucose >  127.50
# |   |--- BMI <= 29.95
# |   |   |--- Glucose <= 145.50
# |   |   |   |--- Insulin <= 132.50
# |   |   |   |   |--- BMI <= 28.15
# |   |   |   |   |   |--- BloodPressure <= 73.00
# |   |   |   |   |   |   |--- Pregnancies <= 2.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  2.50
# |   |   |   |   |   |   |   |--- Pregnancies <= 5.00
# |   |   |   |   |   |   |   |   |--- BMI <= 23.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  23.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pregnancies >  5.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BloodPressure >  73.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- BMI >  28.15
# |   |   |   |   |   |--- Glucose <= 135.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Glucose >  135.00
# |   |   |   |   |   |   |--- Pregnancies <= 9.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  9.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Insulin >  132.50
# |   |   |   |   |--- class: 0
# |   |   |--- Glucose >  145.50
# |   |   |   |--- Age <= 25.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Age >  25.50
# |   |   |   |   |--- Age <= 61.00
# |   |   |   |   |   |--- BMI <= 27.10
# |   |   |   |   |   |   |--- Glucose <= 151.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Glucose >  151.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BMI >  27.10
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.40
# |   |   |   |   |   |   |   |--- BloodPressure <= 82.00
# |   |   |   |   |   |   |   |   |--- BMI <= 27.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  27.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- BloodPressure >  82.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.40
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Age >  61.00
# |   |   |   |   |   |--- class: 0
# |   |--- BMI >  29.95
# |   |   |--- Glucose <= 157.50
# |   |   |   |--- BloodPressure <= 61.00
# |   |   |   |   |--- Age <= 40.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Age >  40.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.44
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.44
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- BloodPressure >  61.00
# |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |--- Insulin <= 260.00
# |   |   |   |   |   |   |--- BMI <= 41.70
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.14
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 81.00
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BloodPressure >  81.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.14
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  41.70
# |   |   |   |   |   |   |   |--- BloodPressure <= 85.50
# |   |   |   |   |   |   |   |   |--- Glucose <= 143.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Glucose >  143.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  85.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Insulin >  260.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.43
# |   |   |   |   |   |   |--- BMI <= 45.55
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.14
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.14
# |   |   |   |   |   |   |   |   |--- BMI <= 32.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  32.45
# |   |   |   |   |   |   |   |   |   |--- BMI <= 33.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BMI >  33.05
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 34.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  34.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- BMI >  45.55
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.43
# |   |   |   |   |   |   |--- BMI <= 38.60
# |   |   |   |   |   |   |   |--- BloodPressure <= 67.00
# |   |   |   |   |   |   |   |   |--- Insulin <= 418.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Insulin >  418.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- BloodPressure >  67.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  38.60
# |   |   |   |   |   |   |   |--- BloodPressure <= 83.00
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  83.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- Glucose >  157.50
# |   |   |   |--- Insulin <= 629.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.34
# |   |   |   |   |   |--- BMI <= 35.30
# |   |   |   |   |   |   |--- Glucose <= 192.00
# |   |   |   |   |   |   |   |--- Glucose <= 177.00
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.28
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.28
# |   |   |   |   |   |   |   |   |   |--- BloodPressure <= 85.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- BloodPressure >  85.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Glucose >  177.00
# |   |   |   |   |   |   |   |   |--- Insulin <= 155.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Insulin >  155.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Glucose >  192.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BMI >  35.30
# |   |   |   |   |   |   |--- BMI <= 46.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  46.80
# |   |   |   |   |   |   |   |--- Pregnancies <= 4.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Pregnancies >  4.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.34
# |   |   |   |   |   |--- Age <= 44.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Age >  44.00
# |   |   |   |   |   |   |--- Pregnancies <= 6.50
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.16
# |   |   |   |   |   |   |   |   |--- Age <= 50.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Age >  50.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  6.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Insulin >  629.50
# |   |   |   |   |--- BloodPressure <= 65.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- BloodPressure >  65.00
# |   |   |   |   |   |--- class: 0

# %% [markdown]
# ### Adversarial Attack: Data Poisoning
# The process of data poisoning involves falsifying a small portion of the labels. In our case, the value of the target feature is "flipped" - for example, we replace a 1 with a 0 (or a 0 becomes a 1). It is a very simple strategy which can have a significant impact on our model's accuracy. Let's flip 5% of the labels.
#
# The below implementation of a data poisoning attack is an adversarial attack based on the example in Chapter 5.9.2.2 of the book.

# %%
#Original dataset distribution
print(f"Original class distribution:\n{dataset['Outcome'].value_counts()}\n")

#Set the percentage of data to poison
poisoning_percentage = 0.05  #5% of the data will be poisoned
num_samples_to_poison = int(len(dataset) * poisoning_percentage)

#Randomly select rows to poison
np.random.seed(42)
poison_indices = np.random.choice(dataset.index, num_samples_to_poison, replace=False)

#Flip the labels for the selected rows
dataset.loc[poison_indices, 'Outcome'] = 1 - dataset.loc[poison_indices, 'Outcome']

#Save the poisoned dataset
poisoned_filename = 'diabetes_poisoned.csv'
dataset.to_csv(poisoned_filename, index=False)
print(f"Poisoned data saved to {poisoned_filename}\n")

#Print the new class distribution
print(f"New class distribution after poisoning:\n{dataset['Outcome'].value_counts()}\n")

#Use the poisoned data to train the model
data_poisoned = pd.read_csv(poisoned_filename)

for column in dataset.columns[:-1]: 
	entropy = calculate_entropy(dataset, column) 
	information_gain = calculate_information_gain(dataset, column, 'Outcome') 
	print(f"{column} - Entropy: {entropy:.3f}, Information Gain: {information_gain:.3f}")

# Feature selection for the first step in making decision tree 
#selected_feature = 'DiabetesPedigreeFunction'

X_poisoned = data_poisoned.drop(columns=['Outcome'])
y_poisoned = data_poisoned['Outcome']

clf_poisoned = DecisionTreeClassifier(criterion='entropy', max_depth=50, random_state=42)
clf_poisoned.fit(X_poisoned, y_poisoned)
y_pred_poisoned = clf_poisoned.predict(X_poisoned)

r = export_text(clf_poisoned, feature_names=list(X.columns))
print(r)

plt.figure(figsize=(20, 10))
plot_tree(
    clf_poisoned,
    feature_names=X.columns,
    class_names=['No Diabetes', 'Diabetes'],
    filled=True,
    rounded=True
)
plt.title("Decision Tree Trained on Poisoned Dataset")
plt.show()

plt.savefig("decision_tree_full.svg", format='svg', dpi=300)
# Out:
# Original class distribution:
# 0    490
# 1    278
# Name: Outcome, dtype: int64
#
# Poisoned data saved to diabetes_poisoned.csv
#
# New class distribution after poisoning:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
#
# Pregnancies - Entropy: 3.482, Information Gain: 0.062
# Glucose - Entropy: 6.751, Information Gain: 0.304
# BloodPressure - Entropy: 4.792, Information Gain: 0.059
# SkinThickness - Entropy: 4.586, Information Gain: 0.082
# Insulin - Entropy: 4.682, Information Gain: 0.277
# BMI - Entropy: 7.594, Information Gain: 0.344
# DiabetesPedigreeFunction - Entropy: 8.829, Information Gain: 0.651
# Age - Entropy: 5.029, Information Gain: 0.141
# |--- Glucose <= 127.50
# |   |--- Age <= 28.50
# |   |   |--- BMI <= 30.95
# |   |   |   |--- Pregnancies <= 7.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.67
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.67
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.69
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.69
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Pregnancies >  7.50
# |   |   |   |   |--- class: 1
# |   |   |--- BMI >  30.95
# |   |   |   |--- BloodPressure <= 37.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- BloodPressure >  37.00
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.50
# |   |   |   |   |   |--- BMI <= 45.35
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.28
# |   |   |   |   |   |   |   |--- Insulin <= 89.00
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 55.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- BloodPressure >  55.00
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.27
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 94.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  94.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Insulin >  89.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.28
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BMI >  45.35
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.50
# |   |   |   |   |   |--- BMI <= 38.65
# |   |   |   |   |   |   |--- SkinThickness <= 39.50
# |   |   |   |   |   |   |   |--- BMI <= 32.20
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BMI >  32.20
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 61.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BloodPressure >  61.00
# |   |   |   |   |   |   |   |   |   |--- BMI <= 34.30
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 32.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  32.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BMI >  34.30
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 36.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  36.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- SkinThickness >  39.50
# |   |   |   |   |   |   |   |--- SkinThickness <= 42.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- SkinThickness >  42.50
# |   |   |   |   |   |   |   |   |--- Insulin <= 128.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Insulin >  128.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BMI >  38.65
# |   |   |   |   |   |   |--- Age <= 21.50
# |   |   |   |   |   |   |   |--- Pregnancies <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pregnancies >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Age >  21.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- Age >  28.50
# |   |   |--- BMI <= 26.35
# |   |   |   |--- BMI <= 9.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- BMI >  9.65
# |   |   |   |   |--- class: 0
# |   |   |--- BMI >  26.35
# |   |   |   |--- Glucose <= 99.50
# |   |   |   |   |--- Glucose <= 28.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Glucose >  28.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.80
# |   |   |   |   |   |   |--- Age <= 42.50
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.17
# |   |   |   |   |   |   |   |   |--- SkinThickness <= 18.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SkinThickness >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.17
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Age >  42.50
# |   |   |   |   |   |   |   |--- SkinThickness <= 24.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- SkinThickness >  24.00
# |   |   |   |   |   |   |   |   |--- SkinThickness <= 31.50
# |   |   |   |   |   |   |   |   |   |--- Glucose <= 72.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Glucose >  72.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SkinThickness >  31.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.80
# |   |   |   |   |   |   |--- SkinThickness <= 35.50
# |   |   |   |   |   |   |   |--- Pregnancies <= 6.00
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.11
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.11
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pregnancies >  6.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SkinThickness >  35.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Glucose >  99.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.56
# |   |   |   |   |   |--- Age <= 54.50
# |   |   |   |   |   |   |--- BMI <= 27.55
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  27.55
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.20
# |   |   |   |   |   |   |   |   |--- Pregnancies <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Pregnancies >  5.50
# |   |   |   |   |   |   |   |   |   |--- BMI <= 34.55
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 118.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  118.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BMI >  34.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.20
# |   |   |   |   |   |   |   |   |--- Pregnancies <= 1.50
# |   |   |   |   |   |   |   |   |   |--- Glucose <= 113.00
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 36.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  36.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Glucose >  113.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Pregnancies >  1.50
# |   |   |   |   |   |   |   |   |   |--- Insulin <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 105.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  105.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Insulin >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- Age >  54.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.56
# |   |   |   |   |   |--- Pregnancies <= 6.50
# |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |--- Age <= 34.50
# |   |   |   |   |   |   |   |   |--- BMI <= 27.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- BMI >  27.20
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Age >  34.50
# |   |   |   |   |   |   |   |   |--- BMI <= 33.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- BMI >  33.15
# |   |   |   |   |   |   |   |   |   |--- Age <= 55.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Age >  55.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Pregnancies >  6.50
# |   |   |   |   |   |   |--- class: 1
# |--- Glucose >  127.50
# |   |--- BMI <= 29.95
# |   |   |--- Glucose <= 145.50
# |   |   |   |--- Insulin <= 132.50
# |   |   |   |   |--- BMI <= 28.15
# |   |   |   |   |   |--- BloodPressure <= 73.00
# |   |   |   |   |   |   |--- Pregnancies <= 2.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  2.50
# |   |   |   |   |   |   |   |--- Pregnancies <= 5.00
# |   |   |   |   |   |   |   |   |--- BMI <= 23.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  23.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pregnancies >  5.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BloodPressure >  73.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- BMI >  28.15
# |   |   |   |   |   |--- Glucose <= 135.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Glucose >  135.00
# |   |   |   |   |   |   |--- Pregnancies <= 9.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  9.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Insulin >  132.50
# |   |   |   |   |--- class: 0
# |   |   |--- Glucose >  145.50
# |   |   |   |--- Age <= 25.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Age >  25.50
# |   |   |   |   |--- Age <= 61.00
# |   |   |   |   |   |--- BMI <= 27.10
# |   |   |   |   |   |   |--- Glucose <= 151.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Glucose >  151.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BMI >  27.10
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.40
# |   |   |   |   |   |   |   |--- BloodPressure <= 82.00
# |   |   |   |   |   |   |   |   |--- BMI <= 27.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  27.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- BloodPressure >  82.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.40
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Age >  61.00
# |   |   |   |   |   |--- class: 0
# |   |--- BMI >  29.95
# |   |   |--- Glucose <= 157.50
# |   |   |   |--- BloodPressure <= 61.00
# |   |   |   |   |--- Age <= 40.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Age >  40.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.44
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.44
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- BloodPressure >  61.00
# |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |--- Insulin <= 260.00
# |   |   |   |   |   |   |--- BMI <= 41.70
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.14
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 81.00
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BloodPressure >  81.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.14
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  41.70
# |   |   |   |   |   |   |   |--- BloodPressure <= 85.50
# |   |   |   |   |   |   |   |   |--- Glucose <= 143.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Glucose >  143.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  85.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Insulin >  260.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.43
# |   |   |   |   |   |   |--- BMI <= 45.55
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.14
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.14
# |   |   |   |   |   |   |   |   |--- BMI <= 32.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  32.45
# |   |   |   |   |   |   |   |   |   |--- BMI <= 33.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BMI >  33.05
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 34.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  34.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- BMI >  45.55
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.43
# |   |   |   |   |   |   |--- BMI <= 38.60
# |   |   |   |   |   |   |   |--- BloodPressure <= 67.00
# |   |   |   |   |   |   |   |   |--- Insulin <= 418.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Insulin >  418.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- BloodPressure >  67.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  38.60
# |   |   |   |   |   |   |   |--- BloodPressure <= 83.00
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  83.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- Glucose >  157.50
# |   |   |   |--- Insulin <= 629.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.34
# |   |   |   |   |   |--- BMI <= 35.30
# |   |   |   |   |   |   |--- Glucose <= 192.00
# |   |   |   |   |   |   |   |--- Glucose <= 177.00
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.28
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.28
# |   |   |   |   |   |   |   |   |   |--- BloodPressure <= 85.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- BloodPressure >  85.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Glucose >  177.00
# |   |   |   |   |   |   |   |   |--- Insulin <= 155.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Insulin >  155.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Glucose >  192.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BMI >  35.30
# |   |   |   |   |   |   |--- BMI <= 46.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- BMI >  46.80
# |   |   |   |   |   |   |   |--- Pregnancies <= 4.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Pregnancies >  4.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.34
# |   |   |   |   |   |--- Age <= 44.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Age >  44.00
# |   |   |   |   |   |   |--- Pregnancies <= 6.50
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.16
# |   |   |   |   |   |   |   |   |--- Age <= 50.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Age >  50.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  6.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Insulin >  629.50
# |   |   |   |   |--- BloodPressure <= 65.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- BloodPressure >  65.00
# |   |   |   |   |   |--- class: 0

# %% [markdown]
# ## The Task
# In this lab, we constructed a decision tree and performed a data poisoning attack. Your task is simple: visualise both the original dataset (stored in the variable "dataset") and the poisoned dataset (stored in the variable "data_poisoned").
#
# First, perform some diagnostics on the model when fitted on each dataset. Inspect the following:
# - accuracy score
# - precision score
# - recall
# - F1-score
# - confusion matrix
#
# You can find information on accuracy score, precision score, recall, F1-score, and confusion matrix [here](https://www.geeksforgeeks.org/confusion-matrix-machine-learning/).
#
# Other useful metrics are the Receiver-operating characteristic curve and the area under the curve, however, these will be covered later in the module.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import warnings
warnings.filterwarnings("ignore")

dataset = pd.read_csv('diabetes.csv')
data_poisoned = pd.read_csv('diabetes_poisoned.csv')

#ORIGINAL DATASET
X_original = dataset.drop(columns=['Outcome'])
y_original = dataset['Outcome']

#predict on the original dataset
y_pred_original = clf.predict(X_original)

#original accuracy, precision, recall, f1, confusion matrix
accuracy_original = accuracy_score(y_original, y_pred_original)
precision_original = precision_score(y_original, y_pred_original, average = 'weighted')
recall_original = recall_score(y_original, y_pred_original, average = 'weighted')
f1_original = f1_score(y_original, y_pred_original, average = 'weighted')
cm_original = confusion_matrix(y_original, y_pred_original)

print("\nMetrics for Original Dataset:")
print(f"Accuracy: {accuracy_original:}")
print(f"Precision: {precision_original}")
print(f"Recall: {recall_original}")
print(f"F1 Score: {f1_original}")

#confusion matrix for the original dataset
ConfusionMatrixDisplay(cm_original, display_labels=['No Diabetes', 'Diabetes']).plot()
plt.title('Confusion Matrix for Original Dataset')
plt.show()

#POISONED DATASET
X_poisoned = data_poisoned.drop(columns=['Outcome'])
y_poisoned = data_poisoned['Outcome']

#predict on the poisoned data
clf_poisoned = DecisionTreeClassifier(criterion='entropy', max_depth=1)
clf_poisoned.fit(X_poisoned, y_poisoned)
y_pred_poisoned = clf_poisoned.predict(X_poisoned)


#poisoned accuracy, precision, recall, f1, confusion matrix
accuracy_poisoned = accuracy_score(y_poisoned, y_pred_poisoned)
precision_poisoned = precision_score(y_poisoned, y_pred_poisoned, average='weighted')
recall_poisoned = recall_score(y_poisoned, y_pred_poisoned, average='weighted')
f1_poisoned = f1_score(y_poisoned, y_pred_poisoned, average='weighted')
cm_poisoned = confusion_matrix(y_poisoned, y_pred_poisoned)

print("\nMetrics for Poisoned Dataset:")
print(f"Accuracy: {accuracy_poisoned}")
print(f"Precision: {precision_poisoned}")
print(f"Recall: {recall_poisoned}")
print(f"F1 Score: {f1_poisoned}")

#confusion matrix for the poisoned dataset
ConfusionMatrixDisplay(cm_poisoned, display_labels=['No Diabetes', 'Diabetes']).plot()
plt.title('Confusion Matrix for Poisoned Dataset')
plt.show()
# Out:
# Metrics for Original Dataset:
# Accuracy: 0.9505208333333334
# Precision: 0.951272910243234
# Recall: 0.9505208333333334
# F1 Score: 0.9507240444740445
# Metrics for Poisoned Dataset:
# Accuracy: 0.7096354166666666
# Precision: 0.7107948215304846
# Recall: 0.7096354166666666
# F1 Score: 0.7101848519127931
